# %% [markdown]
# # 2020 Plant 1 and Plant 2 Solar Power Genertation Report

# %% [markdown]
# ### Report overview
# Exploatory Data Analysis was performed using python programming language to analyse datasets obtained from 2 solar power plants. I analysed the data gathered from solar power plants to;
#
# * Find relationships between different values
# * Which factor affect solar power generation  and
# * use data to figure out need for repair, maintainance and replacement of equipments
#
# ### Variable names description
#
# DATE_TIME: Date and time for each observation and observations was recorded at 15 minute intervals. 3158
# unique values
#
# PLANT_ID: Id number for plant 1, this will be common for the entire data.
#
# SOURCE_KEY: Source key in this file stands for the inverter id.
#
# DC_POWER: Amount of DC power generated by the inverter (source_key) in this 15 minute interval. Units - kW.
#
# AC_POWER: Amount of AC power generated by the inverter (source_key) in this 15 minute interval. Units - kW.
#
# DAILY_YIELD: Daily yield is a cumulative sum of power generated on that day, till that point in time.
#
# TOTAL_YIELD: This is the total yield for the inverter till that point in time.
#
# AMBIENT_TEMPERATURE: This is the ambient temperature at the plant.
#
# MODULE_TEMPERATURE: There's a module (solar panel) attached to the sensor panel. This is the temperature reading for that module.
#
# IRRADIATION: Amount of irradiation for the 15 minute interval.
#
#
# ### Questions answered
#
# 1.  Average value of daily yield of each inverter in plant 1 and plant 2
# 2. What is the average irradiation
# 3. What is the maximum module and ambient temperature? How are they related
# 4. How many inverters are present for each plants
# 5. Which inverter generates maximum DC/AC power
# 6. How is module and ambient temperature affected by irradiation
# 7. What is the efficiency of DC to AC conversion? Can this be used to find faulty inverters
# 8. Does DC to AC conversion varies for the different plants
#
# ### Analysis description
#
# Plant 1 contains 2 dataset, The power generation dataset gathered at the inverter level and The sensor data is gathered at a plant level. Plant 2 also contains 2 dataset, The power generation dataset gathered at the inverter level and The sensor data is gathered at a plant level.
#
# Both datasets from plant 1 and plant 2 were loaded in separate pandas DataFrames.
#
# With my analysis, I provided answers to the above asked questions.
#
# #### These are showned below

# %% [markdown]
# ### 1.  Average value of daily yield of each inverter in plant 1 and plant 2
#
# **Plant 1**
#
# From my analysis, The average value of daily yield was found to be **3295.97 KW** for **plant 1**.
#
# Inverter with source key **VHMLBKoKgIrUVDU** has the highest average value of daily yield of **3407.26 KW**
#
# ![image.png](attachment:image.png)
#
#
# **Plant 2**
#
# The average value of daily yield for **plant 2** was found to be **3294.89 KW**
#
# Inverter with source key **VHMLBKoKgIrUVDU** has the highest average value of daily yield of **3407.26 KW**
#
# ![image-2.png](attachment:image-2.png)
#
# #### Compairing the average daily yield of Plant 1 and Plant 2 for 2020.
#
# There are no much difference between daily yield of solar plant 1 and plant 2.
#
# The average daily yield of plant 1 is **3295.97 KW** while that of plant 2 is **3294.89 KW**. The difference between the 2 plants is about **1.08 KW**
#
# ![image-4.png](attachment:image-4.png)
#
#
# #### More Insight on Daily Yield and Total Yield for both plant 1 and plant 2
#
# ![image-8.png](attachment:image-8.png)
#
#
# ![image-9.png](attachment:image-9.png)

# %% [markdown]
# ### 2. What is the average irradiation
#
# I analysed the average irradiation by dividing the total irradiation by 34.
#
# **Note** The datasets used for the analysis was gathered at two solar power plants over a 34 day period.
#
# The result of this gave the average irradiation for **plant 1** to be **21.37**  and **plant 2** to be **22.31**

# %% [markdown]
# ### 3. What is the maximum module and ambient temperature? How are they related
#
# Based on my analysis, the ambient temperature for plant 1 and plant 2 was found to be:
#
# * Ambient Temperature   **35.25** (Plant 1)
# * Ambient Temperature    **39.18** (Plant 2)
#
# **Relationshp between the Ambient Temperature of plant 1 and plant 2**
#
# ![image-2.png](attachment:image-2.png)
#
# While that of module temperature for both plant 1 and 2 was found to be:
#
# * module_temperature     65.55 (Plant 1)
# * module_temperature     66.64 (Plant 2)
#
# **Relationshp between the Module Temperature of plant 1 and plant 2**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4. How many inverters are present for each plants
#
# The Total Number of Inverters in plant 1 is: 22
#
# The Total Number of Inverters in plant 2 is: 22
#
# It appears both plant has same number os inverters

# %% [markdown]
# ### 5. Which inverter generates maximum DC/AC power for the whole year
#
# I found the index of the maximum dc power and ac power Plant_1_Generation_Data and finding the source key (inverter) that match with the index of maximum dc power and ac power
#
# With this I was able to find out the inverter with maximum dc power and ac power in plant 1
#
# * Inverter with max dc_power:  **wCURE6d3bPkepu2**
# * Inverter with max ac_power:  **wCURE6d3bPkepu2**
#
# Analysis shows that only inverter with source key(id) **wCURE6d3bPkepu2** has the maximum dc power and ac power in plant 1
#
# **For plant 2:**
#
# * Inverter with max dc_power:  **ZoEaEvLYb1n2sOq**
# * Inverter with max ac_power:  **ZoEaEvLYb1n2sOq**
#
# Analysis shows that only inverter with source key(id) **ZoEaEvLYb1n2sOq** has the maximum dc power and ac power in plant 2

# %% [markdown]
# ### 6. How is module and ambient temperature affected by irradiation
#
# ![image-3.png](attachment:image-3.png)
# **correlation between module and ambient temperature for plant 1**
#
# The chart above shows the correlation between irradiation, module temperature and ambient temperature in plant 1
#
# But the area of our interest is the correlation between module temperature and ambient temperature.
#
# Correlation between module temperature and ambient temperature was found to be **0.853778** for plant 1 which indicate that there is a strong correlation between the two variables
#
#
#
#
#
# ![image-4.png](attachment:image-4.png)
# **correlation between module and ambient temperature for plant 2**
#
# The chart above shows the correlation between irradiation, module temperature and ambient temperature in plant 2
#
# Also for plant 2, The correlation between module temperature and ambient temperature was found to be **0.847273** which indicate that there is a strong correlation between the two variables

# %% [markdown]
# ### 7. What is the efficiency of DC to AC conversion? Can this be used to find faulty inverters
#
# The visual below shows the efficiency of DC to AC conversion for inverters in plant 1
#
# From the chart below, it appears that inverters with source id **1BY6WEcLGh8j5v7** and **bvBOhCH3iADSZry** are underperforming compared to other inverters, perharps these inverters require maintenance or require to be replaced.
#
# ![image.png](attachment:image.png)
#
#
# The visual below shows the efficiency of DC to AC conversion for inverters in plant 2
#
# Same goes for the inverters in plant 2, here the visual shows that inverters with source id **Et9kgGMDl729KT4** and **Quc1TzYxW2pYoWX** are underperforming compared to other inverters, perharps these inverters require maintenance or require to be replaced.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 8. Does DC to AC conversion varies for the different plants
#
# * DC to AC conversion ratio ia an indicator of the effiency of the inverters in both solar plants
#
# * I plotted the DC to AC conversion ratio values with time, I found out that the inverters in plant 2 are much more efficient  at convertion than plant 1 which leads to huge losses in power generation at plant 1.
#
# * Even though the total yield are compairable, thee is a huge discripancy in the DC power generated over the same period of time.
#
# **The chart below shows the conversion ratios of DC to AC**
#
# ![image-3.png](attachment:image-3.png)
# **DC to AC conversion ratio for plant 1**
#
# ![image-4.png](attachment:image-4.png)
# **DC to AC conversion ratio for plant 2**
